# %% [markdown]
# ***ITEM 4: Piloto con mayor cantidad de puntos en total, cuyo constructor sea de nacionalidad sea American o British***

# %%
import pandas as pd
import numpy as np

# %%
# levantamos los json pertinentes:
df_results = pd.read_json(r'C:\Users\aalbe\OneDrive\Escritorio\PI01_DATA02\Datasets/results.json')
df_drivers = pd.read_json(r'C:\Users\aalbe\OneDrive\Escritorio\PI01_DATA02\Datasets/drivers.json')
df_constructors = pd.read_json(r'C:\Users\aalbe\OneDrive\Escritorio\PI01_DATA02\Datasets/constructors.json')

# %%
df_constructors
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            209          manor  Manor Marussia     British
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# 2    http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3    http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4     http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# ..                                                 ...
# 206      http://en.wikipedia.org/wiki/Manor_Motorsport
# 207          http://en.wikipedia.org/wiki/Haas_F1_Team
# 208  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 209   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 210        http://en.wikipedia.org/wiki/Alpine_F1_Team
#
# [211 rows x 5 columns]

# %%
df_results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 24955     24961    1047       841             51     99    14       16
# 24956     24962    1047       849              3      6    18       17
# 24957     24963    1047       825            210     20    20       18
# 24958     24964    1047       850            210     51    17       19
# 24959     24965    1047       815            211     11    19       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# 0                1              1    10.0    58  1:34:50.616      5690616
# 1                2              2     8.0    58       +5.478      5696094
# 2                3              3     6.0    58       +8.163      5698779
# 3                4              4     5.0    58      +17.181      5707797
# 4                5              5     4.0    58      +18.014      5708630
# ...            ...            ...     ...   ...          ...          ...
# 24955           16             16     0.0    54           \N           \N
# 24956           17             17     0.0    54           \N           \N
# 24957           18             18     0.0    54           \N           \N
# 24958           19             19     0.0    53           \N           \N
# 24959            R             20     0.0     8           \N           \N
#
#       fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0             39    2       1:27.452           218.3         1
# 1             41    3       1:27.739         217.586         1
# 2             41    5       1:28.090         216.719         1
# 3             58    7       1:28.603         215.464         1
# 4             43    1       1:27.418         218.385         1
# ...          ...  ...            ...             ...       ...
# 24955         29    7       1:41.675          196.65        11
# 24956         49   16       1:42.497         195.073        11
# 24957         50   13       1:41.999         196.025        11
# 24958         50    8       1:41.707         196.588        12
# 24959          6   19       1:43.263         193.625         7
#
# [24960 rows x 18 columns]

# %%
results_y_constructors = pd.merge(df_results, df_constructors, on = 'constructorId')

# %%
# máscara que filtra el df mergeado para obtener sólo constructors british o american
british_o_american = results_y_constructors['nationality'].isin(['British','American'])

# %%
# el conductor con driverId = 18 tiene mayor cantidad de puntos, con un total de 222 puntos.
results_y_constructors[british_o_american].groupby('driverId')['points'].count().sort_values(ascending = False)
# Out:
# driverId
# 18     222
# 119    209
# 289    179
# 137    175
# 14     175
#       ...
# 634      1
# 635      1
# 636      1
# 637      1
# 851      1
# Name: points, Length: 628, dtype: int64

# %%
df_results_y_constructors = pd.DataFrame(results_y_constructors[british_o_american].groupby('driverId')['points'].count().sort_values(ascending = False))

# %%
df_results_y_constructors.reset_index(inplace = True)

# %%
df_results_y_constructors['points'][0]
# Out:
# 222

# %%
drivers_y_df_results_y_constructors = pd.merge(df_results_y_constructors, df_drivers, on = 'driverId')

# %%
piloto_mas_puntos = drivers_y_df_results_y_constructors['points'] == drivers_y_df_results_y_constructors['points'].max()

# %%
drivers_y_df_results_y_constructors['name'][piloto_mas_puntos].to_string(index = False)
# Out:
# 'Jenson Button'
